# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
from scipy import stats
import googlemaps
from datetime import datetime
from pandas.io.json import json_normalize
# %matplotlib inline

# %%
"""
Read in data
"""

# sold data
#sold = pd.read_json('sold2.jl',lines=True)

# sale data
sale = pd.read_json('sale_allscrapes.jl',lines=True)

income = pd.read_csv('income_zip.csv')

"""
clean and format data
"""

### trulia data ###

# list of filtering parameters
clean = ['url','address','city_state','price','address','bedrooms','bathrooms','area','year_built']#,'lot_size']

# drop duplicate rows
sale = sale.drop_duplicates(clean)

# drop data with missing data in clean
sale = sale.dropna(subset = clean)

# separate out zip code from city/state
sale['Zip'] = sale.city_state.str.split().str[2]

# convert zip to integer
sale.Zip = pd.to_numeric(sale.Zip, downcast='integer', errors='coerce')

# remove any missing zip codes
sale = sale.dropna(subset = ['Zip'])

### census data ###

# convert from strings to integers and remove commas
income.Median = pd.to_numeric(income.Median.str.replace(',',''), downcast = 'integer', errors='coerce')
income.Mean = pd.to_numeric(income.Mean.str.replace(',',''), downcast = 'integer', errors='coerce')
income.Pop = pd.to_numeric(income.Pop.str.replace(',',''), downcast = 'integer', errors='coerce')

# merge in income data
sale = pd.merge(sale,income,on='Zip')

# rename columns for consistancy
sale.rename(index=str, columns={'Zip':'zipcode'}, inplace=True)
sale.rename(index=str, columns={'Median':'median_income'}, inplace=True)
sale.rename(index=str, columns={'Mean':'mean_income'}, inplace=True)
sale.rename(index=str, columns={'Pop':'population'}, inplace=True)

#resulting size
print(str(sale.shape[0]) + ' viable house sale data points')
# Out:
# 8083 viable house sale data points

# %%
sale.address.iloc[15]
# Out:
# '6128 N Keating Ave'

# %%
"""
testing google distance matrix
"""

gmaps = googlemaps.Client(key='AIzaSyBK1EC3HJQaQWVWB_x-h6ffkr-nA7lD5lE')

start_address = '50 W Washington St'
start_city_state = 'Chicago, IL 60603'

arrival_time = datetime.now()
arrival_time = arrival_time.replace(minute=0, hour=9, second=0, year=2018, month=11, day=17)

directions_result = gmaps.directions(sale.address.iloc[15] + sale.city_state.iloc[15],
                                     start_address + start_city_state,
                                     mode='transit',
                                     arrival_time=arrival_time)

# %%
directions_result
# Out:
# [{'bounds': {'northeast': {'lat': 41.99232749999999, 'lng': -87.627693},
#    'southwest': {'lat': 41.880045, 'lng': -87.7471727}},
#   'copyrights': 'Map data ©2018 Google',
#   'legs': [{'arrival_time': {'text': '8:54am',
#      'time_zone': 'America/Chicago',
#      'value': 1542466462},
#     'departure_time': {'text': '7:48am',
#      'time_zone': 'America/Chicago',
#      'value': 1542462498},
#     'distance': {'text': '13.1 mi', 'value': 21126},
#     'duration': {'text': '1 hour 6 mins', 'value': 3964},
#     'end_address': '10 S Dearborn St, Chicago, IL 60603, USA',
#     'end_location': {'lat': 41.88110520000001, 'lng': -87.6294411},
#     'start_address': '6128 N Keating Ave, Chicago, IL 60646, USA',
#     'start_location': {'lat': 41.99232749999999, 'lng': -87.7471727},
#      {'distance': {'text': '8.1 mi', 'value': 13013},
#       'duration': {'text': '28 mins', 'value': 1680},
#       'end_location': {'lat': 41.880745, 'lng': -87.627693},
#       'html_instructions': 'Subway towards 95th',
#       'polyline': {'points': '{{f_Gvz_vOA?jIIzFGvDGnIGfPQbJIdMGvK?vCEvDGrBEd@Ed@Gv@YnAa@|AYvE{@z@EnLoB~RUpIIpKMbBET?XCXMLQPSNUDW@a@AaB?_CB}B@k@F[JQJKLKNGT?h@C`CGzADvD?~AA~MCxC?jBAjHQtDCXGZIZ?b@C~@AnACx@@f@B|@Dd@D`AClAC|BCvDC^?fAAzA?v@?jEGzACrDGn@?lCEpAEzAAhGKlAAlBEdCExBCvBE|CE`DEv@ArCAhBCfFEzBA~@CpHGfJKtBCdQSZ?xAAxACtHKxHI|C?TAN?PKJOfC{DbBmCxEoHJOpDwFfImMxTk]jBwCVk@Ni@Ho@?}@EiKIuNGsMAoCEsMB_@DUDIHKJCVE~ACnEu@rJI~EElNSpEGjHGdJIbCC|DCtEAjJItJUj@@xBC~@?~HMlNK'},
#       'start_location': {'lat': 41.983505, 'lng': -87.658836},
#       'transit_details': {'arrival_stop': {'location': {'lat': 41.880745,
#          'lng': -87.627693},
#         'name': 'Monroe'},
#        'arrival_time': {'text': '8:52am',
#         'time_zone': 'America/Chicago',
#         'value': 1542466320},
#        'departure_stop': {'location': {'lat': 41.983505, 'lng': -87.658836},
#         'name': 'Bryn Mawr'},
#        'departure_time': {'text': '8:24am',
#         'time_zone': 'America/Chicago',
#         'value': 1542464640},
#        'headsign': '95th',
#        'line': {'agencies': [{'name': 'Chicago Transit Authority',
#           'phone': '1 888-YOURCTA',
#           'url': 'http://transitchicago.com/'}],
#         'color': '#c62828',
#         'name': 'Red Line',
#         'text_color': '#ffffff',
#         'url': 'http://www.transitchicago.com/redline/',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/us-chicago-subway.png',
#          'name': 'Subway',
#          'type': 'SUBWAY'}},
#        'num_stops': 14},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 mi', 'value': 235},
#       'duration': {'text': '3 mins', 'value': 174},
#       'end_location': {'lat': 41.88110520000001, 'lng': -87.6294411},
#       'html_instructions': 'Walk to 10 S Dearborn St, Chicago, IL 60603, USA',
#       'polyline': {'points': 'gur~FdyyuOC~G?PM@iB?M?u@DU?'},
#       'start_location': {'lat': 41.880045, 'lng': -87.6278676},
#       'steps': [{'distance': {'text': '404 ft', 'value': 123},
#         'duration': {'text': '1 min', 'value': 87},
#         'end_location': {'lat': 41.8801306, 'lng': -87.6294058},
#         'html_instructions': 'Head <b>west</b> on <b>W Marble Pl</b> toward <b>S Dearborn St</b>',
#         'polyline': {'points': 'gur~FdyyuOC~G?PM@'},
#         'start_location': {'lat': 41.880045, 'lng': -87.6278676},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '367 ft', 'value': 112},
#         'duration': {'text': '1 min', 'value': 87},
#         'end_location': {'lat': 41.88110520000001, 'lng': -87.6294411},
#         'html_instructions': 'Turn <b>right</b> onto <b>S Dearborn St</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'yur~FxbzuOiB?M?u@DU?'},
#         'start_location': {'lat': 41.8801306, 'lng': -87.6294058},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'ash_GxbqvOxNAC{EMCCcDGwJAeBCoA?{A?sDC{BCwL?qBEwD?sCCsD@}JEaCCwEC}EBkE?}FKqD?_E?_BCwA?oBIyI?aEA}CEcJ?qCCuACyAAuDDmAEuA?oD?wAD{AC}BCsA?}ACeE@eCAaCE{E@sEBmD?{CCiDCcHAsGCyD?mBB{ICyCEsDCyA@yA@[EaB?}DC}ADuAEqCAuD@gDCmCFeD@}C?cAEmA?uACuACuD?mACyAAgDAoCBe@Ak@AcBAoCDw@OaUOk`@CiE@oEjAcDnBcFBi@b@aA`@}@nA}BpAiC~@qBZk@f@eAh@_Ah@aAjA_ClA_CrCiFn@kAR]Pg@h@iArAiCrAyCl@eAf@_AZm@Vc@Hi@@{ABuACYl@BG?AW?GT?na@a@j[[dMGvK?nIMxCKd@Gv@YnAa@|AYvE{@z@EnLoB~RUbVWxBEXCXM^e@NUDW?cCB}FHgAV]\\S~@C`CGzADvGAxRCjBAjHQtDCXGZIZ?bBEnACx@@dBHd@D`ACjEGzJErOSjJMjQYpPU|OMtYYpXYnKOvMId@APKJOjFiIdF_I~g@ix@f@uAHo@?}@O_[IcRAsNJ_@HKJCVE~ACnEu@rJIlUY|NOhNMrKEjJItJUdDA~JMlNKjCb@C~G?PM@wB?kAD'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta.    Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
df = json_normalize(directions_result)

# %%
date = datetime.now()
date = date.replace(minute=0, hour=9, second=0, year=2018, month=11, day=17)
print(date)
# Out:
# 2018-11-17 09:00:00.765005

# %%
"""
Check initial correlations
"""

# filter down to correlation parameters
sale = sale.filter(['price','bedrooms','bathrooms','area','year_built','median_income','mean_income'],axis=1)

# filter out outliers
sale = sale[(np.abs(stats.zscore(sale)) < 3).all(axis=1)]

# correlation matrix

corr = sale.corr()

# %%
"""
Plotting
"""

### pair plot ###

## plot the pairplot
initial_pairs = sns.pairplot(sale,diag_kind='kde')

# ### heatmap ###

# # #initialize figure
# # fig, ax = plt.subplots(1,1, figsize = (1, 5), dpi=300)

# # plot the heatmap
# sns.heatmap(corr, annot = True,
#         xticklabels=corr.columns,
#         yticklabels=corr.columns,
#        cmap="cividis")
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
